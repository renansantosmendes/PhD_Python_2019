# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
#from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.contrib.layers import fully_connected
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-db6a5b6b6a53> in <module>()
#       4 import tensorflow as tf
#       5 #from tensorflow.examples.tutorials.mnist import input_data
# ----> 6 from tensorflow.contrib.layers import fully_connected
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/contrib/__init__.py in <module>()
#      23
#      24 # Add projects here, they will show up under tf.contrib.
# ---> 25 from tensorflow.contrib import autograph
#      26 from tensorflow.contrib import batching
#      27 from tensorflow.contrib import bayesflow
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/contrib/autograph/__init__.py in <module>()
#      22 from __future__ import print_function
#      23
# ---> 24 from tensorflow.python.autograph import *  # pylint:disable=wildcard-import
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/__init__.py in <module>()
#      33
#      34 # TODO(mdan): Bring only the relevant symbols to the top level.
# ---> 35 from tensorflow.python.autograph import operators
#      36 from tensorflow.python.autograph import utils
#      37 from tensorflow.python.autograph.core.converter import ConversionOptions
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/operators/__init__.py in <module>()
#      38 from __future__ import print_function
#      39
# ---> 40 from tensorflow.python.autograph.operators.control_flow import for_stmt
#      41 from tensorflow.python.autograph.operators.control_flow import if_stmt
#      42 from tensorflow.python.autograph.operators.control_flow import while_stmt
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/operators/control_flow.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.autograph.operators import py_builtins
#      22 from tensorflow.python.data.ops import dataset_ops
#      23 from tensorflow.python.framework import tensor_util
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/operators/py_builtins.py in <module>()
#      24 import six
#      25
# ---> 26 from tensorflow.python.autograph.utils import py_func
#      27 from tensorflow.python.autograph.utils import tensors
#      28 from tensorflow.python.framework import constant_op
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/utils/__init__.py in <module>()
#      22 from tensorflow.python.autograph.utils.misc import alias_tensors
#      23 from tensorflow.python.autograph.utils.py_func import wrap_py_func
# ---> 24 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#      25 from tensorflow.python.autograph.utils.testing import fake_tf
#      26 from tensorflow.python.autograph.utils.type_check import is_tensor
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/autograph/utils/tensor_list.py in <module>()
#      20
#      21 from tensorflow.python.framework import ops
# ---> 22 from tensorflow.python.ops import list_ops
#      23 from tensorflow.python.ops import tensor_array_ops
#      24
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/list_ops.py in <module>()
#      24 from tensorflow.python.framework import tensor_shape
#      25 from tensorflow.python.ops import array_ops
# ---> 26 from tensorflow.python.ops import gen_list_ops
#      27 # go/tf-wildcard-import
#      28 # pylint: disable=wildcard-import
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/gen_list_ops.py in <module>()
#      22 from tensorflow.python.framework import ops as _ops
#      23 from tensorflow.python.framework import op_def_library as _op_def_library
# ---> 24 from tensorflow.python.util.deprecation import deprecated_endpoints
#      25 from tensorflow.python.util import dispatch as _dispatch
#      26 from tensorflow.python.util.tf_export import tf_export
#
# ImportError: cannot import name 'deprecated_endpoints'

# %%
from sklearn.datasets import fetch_openml
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
mnist = fetch_openml('mnist_784', version=1, cache=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2e3595ec4660> in <module>()
# ----> 1 mnist = fetch_openml('mnist_784', version=1, cache=True)
#
# /usr/local/lib/python3.4/dist-packages/sklearn/datasets/openml.py in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y)
#     606     # obtain the data
#     607     arff = _download_data_arff(data_description['file_id'], return_sparse,
# --> 608                                data_home)
#     609     arff_data = arff['data']
#     610     # nominal attributes is a dict mapping from the attribute name to the
#
# /usr/local/lib/python3.4/dist-packages/sklearn/datasets/openml.py in _download_data_arff(file_id, sparse, data_home, encode_nominal)
#     373         return arff_file
#     374
# --> 375     return _arff_load()
#     376
#     377
#
# /usr/local/lib/python3.4/dist-packages/sklearn/datasets/openml.py in wrapper()
#      50                 return f()
#      51             try:
# ---> 52                 return f()
#      53             except HTTPError:
#      54                 raise
#
# /usr/local/lib/python3.4/dist-packages/sklearn/datasets/openml.py in _arff_load()
#     370                 arff_file = _arff.loads(response.read().decode('utf-8'),
#     371                                         encode_nominal=encode_nominal,
# --> 372                                         return_type=return_type)
#     373         return arff_file
#     374
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in loads(s, encode_nominal, return_type)
#    1029     decoder = ArffDecoder()
#    1030     return decoder.decode(s, encode_nominal=encode_nominal,
# -> 1031                           return_type=return_type)
#    1032
#    1033 def dump(obj, fp):
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in decode(self, s, encode_nominal, return_type)
#     846         try:
#     847             return self._decode(s, encode_nominal=encode_nominal,
# --> 848                                 matrix_type=return_type)
#     849         except ArffException as e:
#     850             e.line = self._current_line
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in _decode(self, s, encode_nominal, matrix_type)
#     816             # DATA INSTANCES --------------------------------------------------
#     817             elif STATE == _TK_DATA:
# --> 818                 data.decode_data(row, self._conversors)
#     819             # -----------------------------------------------------------------
#     820
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in decode_data(self, s, conversors)
#     437                 raise BadDataFormat(s)
#     438
# --> 439         self.data.append(self._decode_values(values, conversors))
#     440
#     441     @staticmethod
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in _decode_values(values, conversors)
#     444             values = [None if value is None else conversor(value)
#     445                       for conversor, value
# --> 446                       in zip(conversors, values)]
#     447         except ValueError as exc:
#     448             if 'float: ' in str(exc):
#
# /usr/local/lib/python3.4/dist-packages/sklearn/externals/_arff.py in <listcomp>(.0)
#     443         try:
#     444             values = [None if value is None else conversor(value)
# --> 445                       for conversor, value
#     446                       in zip(conversors, values)]
#     447         except ValueError as exc:
#
# KeyboardInterrupt:

# %%
num_inputs=784    #28x28 pixels
num_hid1=392
num_hid2=196
num_hid3=num_hid1
num_output=num_inputs
lr=0.01
actf=tf.nn.relu
