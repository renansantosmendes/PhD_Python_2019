# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pareto = pd.read_csv('pareto_teste.csv', sep=',',header=None)
pareto.columns = 'F1 F2'.split()

pop = pd.read_csv('pop_inicial.csv', sep=',',header=None)
pop.columns = 'F1 F2'.split()

# %%
pareto
# Out:
#                 F1            F2
# 0    178186.709605 -48085.861621
# 1    174305.337148 -47030.015477
# 2    172807.206122 -46615.628345
# 3    173129.076543 -46703.160467
# 4    171773.440808 -46333.201995
# 5    168458.293662 -45451.829704
# 6    164386.026395 -44336.894346
# 7    163355.282125 -44036.113713
# 8    161717.802397 -43639.520328
# 9    163102.909971 -43990.715291
# 10   177667.775714 -47958.976586
# 11   185624.273696 -50086.254908
# 12   160212.879537 -43235.891444
# 13   184075.827923 -49725.605729
# 14   175901.582886 -47439.788258
# 15   174499.529122 -47105.016730
# 16   164063.383298 -44222.790441
# 17   180704.466963 -48822.164080
# 18   175554.514558 -47389.420654
# 19   168142.952780 -45429.833518
# 20   187017.481633 -50484.091697
# 21   161011.549305 -43406.562540
# 22   173973.787548 -46910.961373
# 23   175019.523274 -47254.704250
# 24   184900.205753 -49786.458779
# 25   157707.675623 -42527.868993
# 26   173573.823893 -46833.678093
# ...

# %%
pareto.plot(kind='scatter', x='F1', y='F2', figsize = (8,6))

# %%
pop.plot(kind='scatter', x='F1', y='F2', figsize = (8,6))

# %%
plt.figure(figsize=(8,6))
plt.scatter( x=pareto['F1'], y=pareto['F2'], label = 'Pareto Final')
plt.scatter( x=pop['F1'], y=pop['F2'], label = 'População Inicial')
plt.xlabel('F1',fontsize=20)
plt.ylabel('F2',fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter( x=pareto['F1'], y=pareto['F2'], label = 'Pareto Final')
plt.scatter( x=pop['F1'], y=pop['F2'], label = 'População Inicial')
plt.xlim([160000,200000])
plt.ylim([-54000,-42500])
plt.xlabel('F1',fontsize=20)
plt.ylabel('F2',fontsize=20)
plt.legend()
plt.show()
